# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\LENOVO\OneDrive\Desktop\data_sets\Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df=df.drop('Id',axis=1)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
# find the unique sepallength
df['SepalLengthCm'].nunique()
# Out:
# 35

# %%
# find the unique element of sepalwidth
df['SepalWidthCm'].nunique()
# Out:
# 23

# %%
# find the no of unique element in the petallegth
df['PetalLengthCm'].nunique()
# Out:
# 43

# %%
# find the no of unique element in the petalwidth
df['PetalWidthCm'].nunique()
# Out:
# 22

# %%
# find the how many type of species and which contain no of elements
Species=df['Species'].value_counts()

# %%
Species
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
# plot the pie chart of species
plt.pie(Species,labels=['setosa','versicolor','virginica'],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x131e9d4c9d0>,
# ...
#  [Text(0.5499999702695115, 0.9526279613277875, 'setosa'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'versicolor'),
#   Text(0.5500001486524352, -0.9526278583383436, 'virginica')],
#  [Text(0.2999999837833699, 0.5196152516333385, '33.3%'),
#   Text(-0.5999999999999974, -5.6176054134900006e-08, '33.3%'),
#   Text(0.30000008108314646, -0.5196151954572783, '33.3%')])

# %%
# plot the histogram and distplot of all four of input
plt.figure(figsize=(16,6))
plt.subplot(2,2,1)
sns.distplot(df['SepalLengthCm'],hist=True)

plt.subplot(2,2,2)
sns.distplot(df['SepalWidthCm'],hist=True)

plt.subplot(2,2,3)
sns.distplot(df['PetalLengthCm'],hist=True)

plt.subplot(2,2,4)
sns.distplot(df['PetalLengthCm'],hist=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_23948\803197430.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SepalLengthCm'],hist=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_23948\803197430.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# plot the boxplot of all four columns of our input
plt.figure(figsize=(16,6))
plt.subplot(2,2,1)
sns.boxplot(x=df['SepalLengthCm'])

plt.subplot(2,2,2)
sns.boxplot(x=df['SepalWidthCm'])

plt.subplot(2,2,3)
sns.boxplot(x=df['PetalLengthCm'])

plt.subplot(2,2,4)
sns.boxplot(x=df['PetalLengthCm'])
# Out:
# <Axes: xlabel='PetalLengthCm'>

# %%
# %%time
# plot the pair plot of all columns along with each other
sns.pairplot(df)
# Out:
# CPU times: total: 1.66 s
# Wall time: 1.65 s

# %%
# find the variance of all four of our input
df.select_dtypes(include=['float', 'int']).var()
# Out:
# SepalLengthCm    0.685694
# SepalWidthCm     0.188004
# PetalLengthCm    3.113179
# PetalWidthCm     0.582414
# dtype: float64

# %%
# find the correlation between each other all four our input
df.select_dtypes(include=['float', 'int']).corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
sns.barplot(df)
# Out:
# <Axes: >

# %%
sns.kdeplot(data=df,x='SepalLengthCm',hue='Species')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Density'>

# %%
sns.kdeplot(data=df,x='SepalWidthCm',hue='Species')
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Density'>

# %%
sns.kdeplot(data=df,x='PetalLengthCm',hue='Species')
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Density'>

# %%
sns.kdeplot(data=df,x='PetalWidthCm',hue='Species')
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Density'>

# %%
sns.kdeplot(data=df,x='PetalWidthCm',hue='Species')
sns.ecdfplot(data=df,x='PetalWidthCm',hue='Species')
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Density'>

# %%
sns.heatmap(df.select_dtypes(include=['float', 'int']).corr(),annot=True)
# Out:
# <Axes: >

# %%
x=df.iloc[:,0:4]
y=df.iloc[:,-1]

# %%
x.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %%
from sklearn.feature_selection import SelectKBest,mutual_info_classif
cols=SelectKBest(mutual_info_classif,k=3)
cols.fit(x,y)
x.columns[cols.get_support()]
# Out:
# Index(['SepalLengthCm', 'PetalLengthCm', 'PetalWidthCm'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['Species']=encoder.fit_transform(df['Species'])

# %%
df.sample(5)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 113            5.7           2.5            5.0           2.0        2
# 105            7.6           3.0            6.6           2.1        2
# 37             4.9           3.1            1.5           0.1        0
# 8              4.4           2.9            1.4           0.2        0
# 112            6.8           3.0            5.5           2.1        2

# %%
x_selected=df[['SepalLengthCm','PetalWidthCm']]
y_selected=df['Species']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_selected,y_selected,test_size=0.2,random_state=2)

# %%
x_train.shape
# Out:
# (120, 2)

# %%
x_test.shape
# Out:
# (30, 2)

# %%
x_train.head()
# Out:
#      SepalLengthCm  PetalWidthCm
# 126            6.2           1.8
# 23             5.1           0.5
# 64             5.6           1.3
# 117            7.7           2.2
# 84             5.4           1.5

# %%
y_train.head()
# Out:
# 126    2
# 23     0
# 64     1
# 117    2
# 84     1
# Name: Species, dtype: int32

# %%
x_test
# Out:
#      SepalLengthCm  PetalWidthCm
# 6              4.6           0.3
# 3              4.6           0.2
# 113            5.7           2.0
# 12             4.8           0.1
# 24             4.8           0.2
# 129            7.2           1.6
# 25             5.0           0.2
# 108            6.7           1.8
# 128            6.4           2.1
# 45             4.8           0.3
# 48             5.3           0.2
# 42             4.4           0.2
# 35             5.0           0.2
# 5              5.4           0.4
# 85             6.0           1.6
# 54             6.5           1.5
# 41             4.5           0.3
# 96             5.7           1.3
# 144            6.7           2.5
# 89             5.5           1.3
# 77             6.7           1.7
# 74             6.4           1.3
# 115            6.4           2.3
# 94             5.6           1.3
# 87             6.3           1.3
# 29             4.7           0.2
# 2              4.7           0.2
# ...

# %%
param_grid = {
    'n_estimators': [10,20,40,60,80,100],
    'min_samples_split': [3,5,7,9],
    'max_features': ['sqrt','log2'],
    'max_depth': [3,5,7,9],
    'criterion': ['gini', 'entropy']
}

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, n_jobs=-1,error_score='raise')

# %%
# %%time
grid_search.fit(x_train,y_train)
# Out:
# CPU times: total: 4.89 s
# Wall time: 50.4 s
# GridSearchCV(cv=5, error_score='raise', estimator=RandomForestClassifier(),
#              n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 7, 9],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_split': [3, 5, 7, 9],
#                          'n_estimators': [10, 20, 40, 60, 80, 100]})

# %%
grid_search.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 3,
#  'max_features': 'sqrt',
#  'min_samples_split': 3,
#  'n_estimators': 40}

# %%
grid_search.best_score_
# Out:
# 0.9666666666666668

# %%
rf=RandomForestClassifier(criterion ='gini',max_depth= 3,max_features='sqrt',min_samples_split= 3,n_estimators=40)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=3, min_samples_split=3, n_estimators=40)

# %%
y_pred=rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9333333333333333

# %%
input_data=(4.6,0.3)

input_data_as_numpy_array = np.asarray(input_data)

input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction=rf.predict(input_data_reshaped)
print(prediction)

if(prediction[0]==0):
    print('setosa')
elif (prediction[0]==1):
    print("versicolor")
else:
    print("virginica")
# Out:
# [0]
# setosa
# C:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import pickle
filename='Iris.pkl'
pickle.dump(rf,open(filename,'wb'))

# %%
loaded_model = pickle.load(open('Iris.pkl', 'rb'))

# %%
input_data=(4.6,0.3)

input_data_as_numpy_array = np.asarray(input_data)

input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction=loaded_model.predict(input_data_reshaped)
print(prediction)

if(prediction[0]==0):
    print('setosa')
elif (prediction[0]==1):
    print("versicolor")
else:
    print("virginica")
# Out:
# [0]
# setosa
# C:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
